# %% [markdown]
# <a href="https://colab.research.google.com/github/VividhPandey003/movie_recommendation_system/blob/main/movie_recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('C:/Users/HP/.vscode/Software-Engineering-83/db.sqlite3')
query = "SELECT * FROM books_book;"

# %%
books = pd.read_sql_query(query, conn)
conn.close()

# %%
books
# Out:
#           id                                      title  \
# 0          1                           The Hunger Games
# 1          2  Harry Potter and the Order of the Phoenix
# 2          3                      To Kill a Mockingbird
# 3          4                        Pride and Prejudice
# 4          5                                   Twilight
# ...      ...                                        ...
# 52473  52474                                  Fractured
# 52474  52475                                    Anasazi
# 52475  52476                                     Marked
# 52476  52477                                Wayward Son
# 52477  52478                        Daughter of Helaman
#
#                       series  \
# 0        The Hunger Games #1
# 1            Harry Potter #5
# 2      To Kill a Mockingbird
# 3
# 4       The Twilight Saga #1
# ...                      ...
# 52473             Fateful #2
# 52474      Sense of Truth #2
# 52475      Soul Guardians #1
# 52476
# 52477   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1      There is a door at the end of a silent corrido...
# 2      The unforgettable novel of a childhood in a sl...
# 3      Alternate cover edition of ISBN 9780679783268S...
# 4      About three things I was absolutely positive.\...
# ...                                                  ...
# 52473  The Fateful Trilogy continues with Fractured. ...
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...
# 52477  Fighting in Helaman's army is Keturah's deepes...
#
#                                               characters  numRatings  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...   6376780.0
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...   2507623.0
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...   4501075.0
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...   2998241.0
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...   4964519.0
# ...                                                  ...         ...
# 52473                                                 []       871.0
# 52474                                                 []        37.0
# 52475                                                 []      6674.0
# 52476                                                 []       238.0
# 52477                                                 []       246.0
#
#                                           ratingsByStars  \
# 0      ['3444695', '1921313', '745221', '171994', '93...
# 1      ['1593642', '637516', '222366', '39573', '14526']
# 2      ['2363896', '1333153', '573280', '149952', '80...
# 3      ['1617567', '816659', '373311', '113934', '767...
# 4      ['1751460', '1113682', '1008686', '542017', '5...
# ...                                                  ...
# 52473                  ['311', '310', '197', '42', '11']
# 52474                        ['16', '14', '5', '2', '0']
# 52475             ['2109', '1868', '1660', '647', '390']
# 52476                      ['77', '78', '59', '19', '5']
# 52477                     ['106', '73', '42', '17', '8']
#
#                                                  setting  ...  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...  ...
# 1      ['Hogwarts School of Witchcraft and Wizardry (...  ...
# 2                   ['Maycomb, Alabama (United States)']  ...
# 3      ['United Kingdom', 'Derbyshire, England (Unite...  ...
# 4      ['Forks, Washington (United States)', 'Phoenix...  ...
# ...                                                  ...  ...
# 52473                                                 []  ...
# 52474                                                 []  ...
# 52475                                                 []  ...
# 52476                                                 []  ...
# 52477                                                 []  ...
#
#                                                   genres bookFormat  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...  Hardcover
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...  Paperback
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...  Paperback
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...  Paperback
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...  Paperback
# ...                                                  ...        ...
# 52473  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...       Nook
# 52474                         ['Mystery', 'Young Adult']  Paperback
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...  Paperback
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...  Paperback
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...  Paperback
#
#                                   edition  pages  \
# 0                           First Edition  374.0
# 1                              US Edition  870.0
# 2                                          324.0
# 3      Modern Library Classics, USA / CAN  279.0
# 4                                          501.0
# ...                                   ...    ...
# 52473                                        0.0
# 52474                       First Edition  190.0
# 52475                                      280.0
# 52476                         1st edition  507.0
# 52477                                      201.0
#
#                               publisher  \
# 0                      Scholastic Press
# 1                       Scholastic Inc.
# 2      Harper Perennial Modern Classics
# 3                        Modern Library
# 4             Little, Brown and Company
# ...                                 ...
# 52473                     Cheri Schmidt
# 52474                Bokheim Publishing
# 52475                       CreateSpace
# 52476               Cascada Productions
# 52477                        Bonneville
#
#                                                   awards likedPercent  \
# 0      ['Locus Award Nominee for Best Young Adult Boo...         96.0
# 1      ['Bram Stoker Award for Works for Young Reader...         98.0
# 2      ['Pulitzer Prize for Fiction (1961)', 'Audie A...         95.0
# 3                                                     []         94.0
# 4      ['Georgia Peach Book Award (2007)', 'Buxtehude...         78.0
# ...                                                  ...          ...
# 52473                                                 []         94.0
# 52474                                                 []         95.0
# 52475            ["Readers' Favorite Book Award (2011)"]         84.0
# 52476                                                 []         90.0
# 52477                                                 []         90.0
#
#                                                image_url price book_available
# 0      https://i.gr-assets.com/images/S/compressed.ph...  5.09              1
# 1      https://i.gr-assets.com/images/S/compressed.ph...  7.38              1
# 2      https://i.gr-assets.com/images/S/compressed.ph...  5.05              1
# 3      https://i.gr-assets.com/images/S/compressed.ph...  5.05              1
# 4      https://i.gr-assets.com/images/S/compressed.ph...   2.1              1
# ...                                                  ...   ...            ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...  5.05              1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...  5.05              1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...  7.37              1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...  2.86              1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...   5.2              1
#
# [52478 rows x 21 columns]

# %%
books = books[:10000]

# %%
books = books[['title', 'description','genres', 'author', 'series','publisher', 'awards','characters','setting']]

# %%
books.fillna(value='the',inplace = True)

# %%
books.isnull()
# Out:
#       title  description  genres  author  series  publisher  awards  \
# 0     False        False   False   False   False      False   False
# 1     False        False   False   False   False      False   False
# 2     False        False   False   False   False      False   False
# 3     False        False   False   False   False      False   False
# 4     False        False   False   False   False      False   False
# ...     ...          ...     ...     ...     ...        ...     ...
# 9995  False        False   False   False   False      False   False
# 9996  False        False   False   False   False      False   False
# 9997  False        False   False   False   False      False   False
# 9998  False        False   False   False   False      False   False
# 9999  False        False   False   False   False      False   False
#
#       characters  setting
# 0          False    False
# 1          False    False
# 2          False    False
# 3          False    False
# 4          False    False
# ...          ...      ...
# 9995       False    False
# 9996       False    False
# 9997       False    False
# 9998       False    False
# 9999       False    False
#
# [10000 rows x 9 columns]

# %%
books.dropna(inplace=True)

# %%
books
# Out:
#                                           title  \
# 0                              The Hunger Games
# 1     Harry Potter and the Order of the Phoenix
# 2                         To Kill a Mockingbird
# 3                           Pride and Prejudice
# 4                                      Twilight
# ...                                         ...
# 9995                            Seize the Night
# 9996                                   Showdown
# 9997                        Jerusalem Interlude
# 9998                           Munich Signature
# 9999                                 Afterimage
#
#                                             description  \
# 0     WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1     There is a door at the end of a silent corrido...
# 2     The unforgettable novel of a childhood in a sl...
# 3     Alternate cover edition of ISBN 9780679783268S...
# 4     About three things I was absolutely positive.\...
# ...                                                 ...
# 9995  There are no rules in the dark, no place to fe...
# 9996  Welcome to Paradise. Epic battles of good and ...
# 9997  In August 1938 Hitler’s Brownshirts conquer Cz...
# 9998  Opening in 1936, the Zion Covenant series tell...
# 9999  In the Company of Shadows is a series about tw...
#
#                                                  genres  \
# 0     ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1     ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2     ['Classics', 'Fiction', 'Historical Fiction', ...
# 3     ['Classics', 'Fiction', 'Romance', 'Historical...
# 4     ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...                                                 ...
# 9995  ['Horror', 'Fiction', 'Thriller', 'Mystery', '...
# 9996  ['Christian Fiction', 'Fiction', 'Christian', ...
# 9997  ['Historical Fiction', 'Christian Fiction', 'C...
# 9998  ['Historical Fiction', 'Christian Fiction', 'C...
# 9999  ['M M Romance', 'Dystopia', 'Romance', 'Dark',...
#
#                                                  author  \
# 0                                       Suzanne Collins
# 1             J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                            Harper Lee
# 3             Jane Austen, Anna Quindlen (Introduction)
# 4                                       Stephenie Meyer
# ...                                                 ...
# 9995  Dean Koontz (Goodreads Author), Keith Szarabaj...
# 9996                      Ted Dekker (Goodreads Author)
# 9997      Bodie Thoene (Goodreads Author), Brock Thoene
# 9998      Bodie Thoene (Goodreads Author), Brock Thoene
# 9999  Ais (Goodreads Author), Santino Hassell (Goodr...
#
#                             series                            publisher  \
# 0              The Hunger Games #1                     Scholastic Press
# 1                  Harry Potter #5                      Scholastic Inc.
# 2            To Kill a Mockingbird     Harper Perennial Modern Classics
# 3                                                        Modern Library
# 4             The Twilight Saga #1            Little, Brown and Company
# ...                            ...                                  ...
# 9995              Moonlight Bay #2  Random House Audio Publishing Group
# 9996                   Paradise #1                        Thomas Nelson
# 9997              Zion Covenant #4             Tyndale House Publishers
# 9998              Zion Covenant #3             Tyndale House Publishers
# 9999  In the Company of Shadows #2                Santino Hassell & Ais
#
#                                                  awards  \
# 0     ['Locus Award Nominee for Best Young Adult Boo...
# 1     ['Bram Stoker Award for Works for Young Reader...
# 2     ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3                                                    []
# 4     ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                                                 ...
# 9995                                                 []
# 9996                                                 []
# 9997                                                 []
# 9998                                                 []
# 9999                                                 []
#
#                                              characters  \
# 0     ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1     ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 2     ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...
# 3     ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...
# 4     ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# ...                                                 ...
# 9995                               ['Christopher Snow']
# 9996               ['Marsuvees Black', 'Billy Rediger']
# 9997                                                 []
# 9998                                                 []
# 9999  ['Boyd Kadin Beaulieu', 'Hsin "Sin" Liu Vega',...
#
#                                                 setting
# 0     ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1     ['Hogwarts School of Witchcraft and Wizardry (...
# 2                  ['Maycomb, Alabama (United States)']
# 3     ['United Kingdom', 'Derbyshire, England (Unite...
# 4     ['Forks, Washington (United States)', 'Phoenix...
# ...                                                 ...
# 9995      ['Moonlight Bay, California (United States)']
# 9996                                                 []
# 9997                             ['Jerusalem (Israel)']
# 9998                                                 []
# 9999                                                 []
#
# [10000 rows x 9 columns]

# %%
books.duplicated().sum()
# Out:
# 0

# %%
books.iloc[1]
# Out:
# title                  Harry Potter and the Order of the Phoenix
# description    There is a door at the end of a silent corrido...
# genres         ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# author                 J.K. Rowling, Mary GrandPré (Illustrator)
# series                                           Harry Potter #5
# publisher                                        Scholastic Inc.
# awards         ['Bram Stoker Award for Works for Young Reader...
# characters     ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# setting        ['Hogwarts School of Witchcraft and Wizardry (...
# Name: 1, dtype: object

# %%
# Combine relevant text columns into 'contents' and 'other_info' for each book
books['contents'] = books['description']  + ' ' + books['series'] + ' ' + books['title'] + ' ' + books['characters']

# %%
books['other_info'] = books['genres'] + ' ' + books['publisher'] + ' ' + books['awards'] + ' ' +  books['author'] + ' ' + books['setting']

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps= PorterStemmer()

# %%
def stem_text(text):
    return ' '.join([ps.stem(word) for word in text.split()])

# %%
books['contents'] = books['contents'].apply(stem_text)
#

# %%
books['other_info'] = books['other_info'].apply(stem_text)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=2000,stop_words='english')

# %%
vector_contents = tfidf_vectorizer.fit_transform(books['contents']).toarray()

# %%
#vector_other_info = tfidf_vectorizer.fit_transform(books['other_info']).toarray()

# %%
#similarity_contents = cosine_similarity(vector_contents)
#similarity_other_info = cosine_similarity(vector_other_info)

# %%
#similarity[1]

# %%
def recommend(book_title):
    similarity = cosine_similarity(vector_contents)
    book_index = books[books['title'] == book_title].index[0]
    distances = similarity[book_index]
    # Get top 5 similar books (excluding the book itself)
    similar_books_indices = np.argsort(distances)[::-1][1:10]
    recommended_books = books.iloc[similar_books_indices][['title', 'author', 'genres']]
    print(distances)
    return recommended_books

# %%
def semantic_search(query, books, tfidf_matrix, tfidf_vectorizer):
    query = stem_text(query)
    query_vector = tfidf_vectorizer.transform([query])
    
    # Calculate cosine similarity between query vector and document vectors
    similarities = cosine_similarity(query_vector, tfidf_matrix)
    ranked_indices = similarities.argsort()[0][::-1]  # Sort by descending order of similarity
    print(similarities)
    # Return ranked documents based on similarity
    ranked_documents = books.iloc[ranked_indices]['title']
    print(ranked_documents)
    return ranked_indices

# %%
recommend('Twilight')
# Out:
# [0.01348595 0.02374486 0.07231811 ... 0.01131914 0.00954873 0.02624375]
#                                                   title  \
# 1201                                           New Moon
# 3425                Twilight: The Graphic Novel, Vol. 1
# 2894                                  The Twilight Saga
# 1116                                      Breaking Dawn
# 1112                                            Eclipse
# 2904              The Twilight Saga Complete Collection
# 4375  The Twilight Saga: The Official Illustrated Guide
# 262                           Midnight Sun [2008 Draft]
# 7812                                       Midnight Sun
#
#                                                  author  \
# 1201                                    Stephenie Meyer
# 3425  Young Kim (Art/Adaptation), Stephenie Meyer (C...
# 2894  Stephenie Meyer, Ilyana Kadushin (Narrator), K...
# 1116                                    Stephenie Meyer
# 1112                                    Stephenie Meyer
# 2904                                    Stephenie Meyer
# 4375                                    Stephenie Meyer
# 262                                     Stephenie Meyer
# 7812                                    Stephenie Meyer
#
#                                                  genres
# 1201  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 3425  ['Graphic Novels', 'Young Adult', 'Vampires', ...
# 2894  ['Fantasy', 'Young Adult', 'Romance', 'Vampire...
# 1116  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 1112  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 2904  ['Fantasy', 'Young Adult', 'Vampires', 'Romanc...
# 4375  ['Young Adult', 'Vampires', 'Fantasy', 'Parano...
# 262   ['Young Adult', 'Fantasy', 'Vampires', 'Romanc...
# 7812  ['Fantasy', 'Young Adult', 'Romance', 'Paranor...

# %%
semantic_search('im feeling love',books,vector_contents,tfidf_vectorizer)
# Out:
# [[0.02080908 0.         0.06073342 ... 0.04384008 0.         0.        ]]
# 7933    Between The Lines: Volumes of Words Unspoken
# 352                                 Love You Forever
# 9817              Feeling Good: The New Mood Therapy
# 2782                               The Art of Loving
# 3279                          The Lover's Dictionary
#                             ...
# 7986                                   Andersonville
# 4656                                     Rumble Fish
# 7985          A History of the World in 10½ Chapters
# 4658                             The Little Stranger
# 9999                                      Afterimage
# Name: title, Length: 10000, dtype: object
# array([7933,  352, 9817, ..., 7985, 4658, 9999], dtype=int64)

# %%
recommend("Norwegian Wood")
# Out:
# [0.03090479 0.00328893 0.06064437 ... 0.0055453  0.00935594 0.00714195]
#                                title  \
# 8489                       Flyy Girl
# 5367                    Mythago Wood
# 9255      Conversations with Friends
# 9877                   Pages for You
# 9347         When We Were Very Young
# 8671                          Walden
# 3832                  The Hazel Wood
# 6961                The Raging Quiet
# 8578  The Universe Versus Alex Woods
#
#                                              author  \
# 8489                                     Omar Tyree
# 5367                               Robert Holdstock
# 9255                Sally Rooney (Goodreads Author)
# 9877                               Sylvia Brownrigg
# 9347  A.A. Milne, Ernest H. Shepard (Illustrations)
# 8671                               Michael T. Dolan
# 3832              Melissa Albert (Goodreads Author)
# 6961                                 Sherryl Jordan
# 8578                                  Gavin Extence
#
#                                                  genres
# 8489  ['Fiction', 'African American', 'Urban', 'Youn...
# 5367  ['Fantasy', 'Fiction', 'Mythology', 'Horror', ...
# 9255  ['Fiction', 'Contemporary', 'Literary Fiction'...
# 9877  ['LGBT', 'Fiction', 'Romance', 'Lesbian', 'Que...
# 9347  ['Poetry', 'Childrens', 'Classics', 'Fiction',...
# 8671  ['Classics', 'Fiction', 'Philosophy', 'Contemp...
# 3832  ['Fantasy', 'Young Adult', 'Fiction', 'Fairy T...
# 6961  ['Historical Fiction', 'Young Adult', 'Romance...
# 8578  ['Fiction', 'Young Adult', 'Contemporary', 'Co...

# %%
'''import pickle
with open('C:/Users/HP/.vscode/Software-Engineering-83/recommend_model.pkl', 'wb') as file:
    pickle.dump(vector_contents, file)'''
# Out:
# "import pickle\nwith open('C:/Users/HP/.vscode/Software-Engineering-83/recommend_model.pkl', 'wb') as file:\n    pickle.dump(vector_contents, file)"

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  # You can adjust max_features based on your dataset size
X = tfidf_vectorizer.fit_transform(books['contents'])

# %%
silhouette_scores = []
for n_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %%
kmeans = KMeans(20, random_state=42)
cluster_labels = kmeans.fit_predict(X)

# Add cluster labels to the dataset
books['cluster'] = cluster_labels

# Print the number of books in each cluster
print(books['cluster'].value_counts())
# Out:
# cluster
# 19    9552
# 1      192
# 18     137
# 16      43
# 11      43
# 13      19
# 2        1
# 14       1
# 7        1
# 3        1
# 12       1
# 8        1
# 6        1
# 17       1
# 5        1
# 0        1
# 4        1
# 15       1
# 10       1
# 9        1
# Name: count, dtype: int64

# %%
books[books['cluster'] == 14]
# Out:
#                                                   title  \
# 8938  Creativity, Inc.: Overcoming the Unseen Forces...
#
#                                             description  \
# 8938  “What does it mean to manage well?”From Ed Cat...
#
#                                                  genres  \
# 8938  ['Business', 'Nonfiction', 'Leadership', 'Mana...
#
#                        author series     publisher  \
# 8938  Ed Catmull, Amy Wallace         Random House
#
#                                                  awards characters setting  \
# 8938  ['Financial Times and McKinsey Business Book o...         []      []
#
#                                                contents  \
# 8938  “what doe it mean to manag well?”from ed catmu...
#
#                                              other_info  cluster
# 8938  ['business', 'nonfiction', 'leadership', 'mana...       14
